# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mlr=pd.read_csv('Ames_Housing_Sales.csv')

# %%
mlr.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0     856.0     854.0        0.0  None             3     1Fam       TA
# 1    1262.0       0.0        0.0  None             3     1Fam       TA
# 2     920.0     866.0        0.0  None             3     1Fam       TA
# 3     961.0     756.0        0.0  None             3     1Fam       Gd
# 4    1145.0    1053.0        0.0  None             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... ScreenPorch Street  TotRmsAbvGrd  \
# 0           No       706.0         0.0  ...         0.0   Pave             8
# 1           Gd       978.0         0.0  ...         0.0   Pave             6
# 2           Mn       486.0         0.0  ...         0.0   Pave             6
# 3           No       216.0         0.0  ...         0.0   Pave             7
# 4           Av       655.0         0.0  ...         0.0   Pave             9
#
# ...

# %%
mlr1=mlr._get_numeric_data()

# %%
mlr1.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0     856.0     854.0        0.0             3       706.0         0.0
# 1    1262.0       0.0        0.0             3       978.0         0.0
# 2     920.0     866.0        0.0             3       486.0         0.0
# 3     961.0     756.0        0.0             3       216.0         0.0
# 4    1145.0    1053.0        0.0             4       655.0         0.0
#
#    BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallQual  \
# 0             1             0      150.0            0.0  ...            7
# 1             0             1      284.0            0.0  ...            6
# 2             1             0      434.0            0.0  ...            7
# 3             1             0      540.0          272.0  ...            7
# 4             1             0      490.0            0.0  ...            8
#
#    PoolArea  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  YearBuilt  \
# ...

# %%
mlr1.isnull().any()
# Out:
# 1stFlrSF         False
# 2ndFlrSF         False
# 3SsnPorch        False
# BedroomAbvGr     False
# BsmtFinSF1       False
# BsmtFinSF2       False
# BsmtFullBath     False
# BsmtHalfBath     False
# BsmtUnfSF        False
# EnclosedPorch    False
# Fireplaces       False
# FullBath         False
# GarageArea       False
# GarageCars       False
# GarageYrBlt      False
# GrLivArea        False
# HalfBath         False
# KitchenAbvGr     False
# LotArea          False
# LotFrontage      False
# LowQualFinSF     False
# MSSubClass       False
# MasVnrArea       False
# MiscVal          False
# MoSold           False
# OpenPorchSF      False
# OverallCond      False
# OverallQual      False
# PoolArea         False
# ScreenPorch      False
# TotRmsAbvGrd     False
# TotalBsmtSF      False
# WoodDeckSF       False
# YearBuilt        False
# YearRemodAdd     False
# YrSold           False
# SalePrice        False
# dtype: bool

# %%
import seaborn as sns
corr=mlr1.corr()
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(corr,annot=True,linewidths=.5,ax=ax)
plt.show()

# %%
mlr1.corr()
# Out:
#                1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  \
# 1stFlrSF       1.000000 -0.223710   0.053200      0.104870    0.446596
# 2ndFlrSF      -0.223710  1.000000  -0.026654      0.507574   -0.142969
# 3SsnPorch      0.053200 -0.026654   1.000000     -0.026018    0.023903
# BedroomAbvGr   0.104870  0.507574  -0.026018      1.000000   -0.118036
# BsmtFinSF1     0.446596 -0.142969   0.023903     -0.118036    1.000000
# BsmtFinSF2     0.094006 -0.106641  -0.031442     -0.007734   -0.054966
# BsmtFullBath   0.251470 -0.174004  -0.001370     -0.158250    0.647400
# BsmtHalfBath  -0.000641 -0.021530   0.035611      0.046327    0.060852
# BsmtUnfSF      0.311394 -0.006450   0.020335      0.148676   -0.502954
# EnclosedPorch -0.051324  0.064856  -0.036961      0.051674   -0.096743
# Fireplaces     0.402572  0.192708   0.006232      0.123763    0.253887
# FullBath       0.366051  0.417049   0.033290      0.357911    0.044227
# ...

# %%
import seaborn as sns
sns.boxplot(mlr1['OverallQual'],data=mlr1)

# %%
x=mlr1.iloc[:,:-1]
y=mlr1.SalePrice

# %%
x.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0     856.0     854.0        0.0             3       706.0         0.0
# 1    1262.0       0.0        0.0             3       978.0         0.0
# 2     920.0     866.0        0.0             3       486.0         0.0
# 3     961.0     756.0        0.0             3       216.0         0.0
# 4    1145.0    1053.0        0.0             4       655.0         0.0
#
#    BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallCond  \
# 0             1             0      150.0            0.0  ...            5
# 1             0             1      284.0            0.0  ...            8
# 2             1             0      434.0            0.0  ...            5
# 3             1             0      540.0          272.0  ...            5
# 4             1             0      490.0            0.0  ...            5
#
#    OverallQual  PoolArea  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# ...

# %%
y.head()
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# Name: SalePrice, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x,y)
predict=lr.predict(x)
predict
# Out:
# array([227836.47864444, 196642.70974368, 221781.24036401, ...,
#        228250.37611968, 132671.35594118, 152754.7054361 ])

# %%
x.shape
# Out:
# (1379, 36)

# %%
m=lr.intercept_
m
# Out:
# 499261.44769160415

# %%
c=lr.coef_
c
# Out:
# array([ 1.62850337e+01,  1.65956640e+01,  2.11774725e+01, -1.00174425e+04,
#         9.58353284e+00,  2.30245966e-01,  8.11809564e+03,  1.68342493e+03,
#        -1.49095264e+00,  1.06871697e+01,  3.58145635e+03,  2.28207093e+03,
#         6.95146194e+00,  1.59519110e+04, -6.50218777e+01,  3.22791539e+01,
#        -2.84966553e+03, -2.15478684e+04,  4.87622621e-01, -1.07955775e+02,
#        -6.01543876e-01, -1.91773092e+02,  2.75006510e+01, -5.62981521e-01,
#        -5.79616971e+01, -7.43826640e-01,  5.48998806e+03,  1.83281484e+04,
#        -3.04196831e+01,  5.31998827e+01,  5.37629395e+03,  8.32282617e+00,
#         2.49968435e+01,  3.70825555e+02,  9.99007189e+01, -6.79559883e+02])

# %%
x.iloc[50]
# Out:
# 1stFlrSF          816.0
# 2ndFlrSF            0.0
# 3SsnPorch           0.0
# BedroomAbvGr        2.0
# BsmtFinSF1        104.0
# BsmtFinSF2        712.0
# BsmtFullBath        1.0
# BsmtHalfBath        0.0
# BsmtUnfSF           0.0
# EnclosedPorch       0.0
# Fireplaces          0.0
# FullBath            1.0
# GarageArea        516.0
# GarageCars          2.0
# GarageYrBlt      1963.0
# GrLivArea         816.0
# HalfBath            0.0
# KitchenAbvGr        1.0
# LotArea          8472.0
# LotFrontage       110.0
# LowQualFinSF        0.0
# MSSubClass         90.0
# MasVnrArea          0.0
# MiscVal             0.0
# MoSold              5.0
# OpenPorchSF         0.0
# OverallCond         5.0
# OverallQual         5.0
# PoolArea            0.0
# ScreenPorch         0.0
# TotRmsAbvGrd        5.0
# TotalBsmtSF       816.0
# WoodDeckSF        106.0
# YearBuilt        1963.0
# YearRemodAdd     1963.0
# YrSold           2010.0
# Name: 50, dtype: float64

# %%
mlr1.iloc[50]
# Out:
# 1stFlrSF            816.0
# 2ndFlrSF              0.0
# 3SsnPorch             0.0
# BedroomAbvGr          2.0
# BsmtFinSF1          104.0
# BsmtFinSF2          712.0
# BsmtFullBath          1.0
# BsmtHalfBath          0.0
# BsmtUnfSF             0.0
# EnclosedPorch         0.0
# Fireplaces            0.0
# FullBath              1.0
# GarageArea          516.0
# GarageCars            2.0
# GarageYrBlt        1963.0
# GrLivArea           816.0
# HalfBath              0.0
# KitchenAbvGr          1.0
# LotArea            8472.0
# LotFrontage         110.0
# LowQualFinSF          0.0
# MSSubClass           90.0
# MasVnrArea            0.0
# MiscVal               0.0
# MoSold                5.0
# OpenPorchSF           0.0
# OverallCond           5.0
# OverallQual           5.0
# PoolArea              0.0
# ScreenPorch           0.0
# TotRmsAbvGrd          5.0
# TotalBsmtSF         816.0
# WoodDeckSF          106.0
# YearBuilt          1963.0
# YearRemodAdd       1963.0
# ...

# %%
print ("Predicted House price", lr.predict(x)[81])
#print ("Equation house price", (m+ np.dot(c, x.iloc[[81]].values[0])))
print ("Target price", y[81] )

print ("Residual price", (lr.predict(x)[81] - y[81]))
# Out:
# Predicted House price 181396.34706997738
# Target price 168500.0
# Residual price 12896.347069977375
