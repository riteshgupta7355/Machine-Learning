# %% [markdown]
# <h1><center>Matplotlib</center></h1>

# %% [markdown]
# Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats.
#
# a set of functionalities similar to those of MATLAB.
#
# line plots, scatter plots, bar charts, histograms, pie charts etc.
#
# relatively low-level; some effort needed to create advanced visualization.

# %% [markdown]
# # Line Chart

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,3,5,7,9]
y=[1,3,5,7,9]
plt.plot(x,y) # Plotting graph
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0.0,6.0,0.01)
y=[x**2 for x in x]
plt.plot(x,y)
plt.show()

# %%
# multiple lines on the same graph
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,10)
y1=x+2
y2=x*6
y3=x/5
plt.plot(x,y1,x,y2,x,y3)
plt.show()

# %%
#Adding grids,axes,labels,markers on a multiple line graph
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,10)
y1=x+2
y2=x*6
y3=x/5
plt.plot(x,y1,'g--',label='y1')
plt.plot(x,y2,color="pink",label='y2')
plt.plot(x,y3,'r-o',label='y3')
plt.grid(True)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %%
#Adding grids,axes,labels,markers on a multiple line graph
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(1,10)
y1=x+2
y2=x*6
y3=x/5
plt.plot(x,y1,'r--',label='y1')
plt.plot(x,y2,color="green",label='y2')
plt.plot(x,y3,'b-o',label='y3')
plt.grid(True)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(bbox_to_anchor=(1, 1)) # Moving legend to outside of graph
plt.show()

# %%
import matplotlib.pyplot as plt
year=[1960,1970,1980,1990,2000,2010]
pop_us=[44.9,45.23,55.23,56.21,57.2,59.3]
pop_ind=[441.9,452.23,553.23,564.21,575.2,596.3]
plt.figure(figsize=(10,10)) # figure size
plt.plot(year,pop_us,color='green')
plt.plot(year,pop_ind,color='orange')
plt.xlabel('countries')
plt.ylabel('year')
plt.title('India population vs US population over different years',color='b')
plt.show()

# %% [markdown]
# # Bar Chart

# %%
import matplotlib.pyplot as plt
height=[3,12,45,78]
bars=('a','b','c','d')
plt.bar(bars,height)
plt.title('Bar Graph')
plt.xlabel('bars')
plt.ylabel('height')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar([1,2,3],[5,2,1])
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple bar chart')
plt.show()

# %%
import matplotlib.pyplot as plt
student_name=["Jhon","Sahil","Monica","Lara"]
marks=[75,98,53,70]
plt.bar(student_name,marks)
plt.xlabel('Student_name')
plt.ylabel('Marks')
plt.title('simple bar chart')
plt.show()

# %% [markdown]
# # Pie Chart

# %%
import matplotlib.pyplot as plt
languages=["Python","Java","C++"]
percentage=[60,30,10]
plt.pie(percentage,labels=languages)
plt.title("simple Pie-Chart")
plt.show()

# %%
# More Options in Pie chart
import matplotlib.pyplot as plt
labels='python','c++','java','ruby'
sizes=[90,50,40,110]
colors=['gold','grey','green','blue']
explode=(0,0,0.2,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.axis('equal')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt
x=[1,2,4,5]
y=[8,5,6,9]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(100)
y=np.random.rand(100)
plt.title("simple scatter plot")
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
gaussian_numbers=np.random.randn(1000)
plt.hist(gaussian_numbers)
plt.title('Gaussian Histogram')
plt.xlabel('value')
plt.ylabel('frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
cars=pd.read_csv('mtcars.csv')
cars
# Out:
#                  C_name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
plt.figure(figsize=(10,7))
cars['mpg'].plot(kind='bar')
plt.show()
#plt.savefig('bargrah.jpeg')

# %%
cars['mpg'].plot(kind='hist')
plt.show()

# %%
cars['mpg'].plot(kind='pie')

# %%
x=cars['mpg']
y=cars['disp']
plt.scatter(x,y)
plt.show()

# %%
plt.figure(figsize=(10,7))
cars['mpg'].plot(kind='line')
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
cars['mpg'].plot()
index=np.arange(len(cars['C_name']))
plt.xticks(index,cars.C_name,rotation=90)
ax.set_yticklabels(cars.mpg,rotation=60,fontsize='medium')
ax.set_title('Miles per gallon of cars in Cars')
ax.set_xlabel('carnames')
ax.set_ylabel('miles/gal')
ax.legend(loc='best')
ax.annotate('Honda Civic',xy=(18,30.4),arrowprops=dict(facecolor='blue'))
ax.annotate('Fiat X1-9',xy=(25,27.3),arrowprops=dict(facecolor='g'))
# Out:
# Text(25, 27.3, 'Fiat X1-9')

# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,5,11)
y=x**2
fig,(ax1,ax2)=plt.subplots(ncols=2,nrows=1)
ax1.plot(x,y,'m')
ax2.plot(y,x,'g')
ax1.set_xlabel('x-axis')
ax1.set_ylabel('y-axis')
ax2.set_xlabel('x-axis')
ax2.set_ylabel('y-axis')
ax1.set_title('parabola')
ax2.set_title('inversed parabola')
plt.show()

# %%
# saving a figure
fig.savefig('sub.jpeg')

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,(ax1,ax2,ax3)=plt.subplots(3,1)
x=np.linspace(0,5,10)
y=x**2
ax1.plot(x,y)
ax2.plot(x,y)
ax3.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)


t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), color='tab:blue', marker='o')
plt.plot(t2, f(t2), color='black')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), color='tab:orange', linestyle='--')
plt.show()

# %%
import matplotlib.pyplot as plt
x=np.linspace(0,10,10)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1]) #fig.add_axes([left,bottom,width,height])
ax.plot(x,x**2,label="x**2")
ax.plot(x,x**3,label="x**3")
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]
fig=plt.figure()
ax=fig.add_axes([1,.1,1,1])
ax.set_xlim([0,10])
ax.set_ylim([0,12])
ax.plot(x,y)
plt.show()

# %%
fig=plt.figure()
fig,(ax1,ax2)=plt.subplots(1,2)
ax1.plot(x)
ax2.plot(y,x)
plt.show()
